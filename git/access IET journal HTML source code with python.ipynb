# %%
import requests
from bs4 import BeautifulSoup
import csv
from selenium import webdriver
import re
from lxml import html
import time

# %%
def extract_pdf_links_from_webpage(url, csv_output_path):

    driver = webdriver.Chrome()
    driver.implicitly_wait(0.5)
    driver.get(url)
    print(url)
    # access HTML source code with page_source method
    s = driver.page_source
    #soup = BeautifulSoup(driver.page_source,"lxml")
    if len(s) != 0:
        tree = html.fromstring(s)
        links = tree.xpath('//a/@href')
        pdf_links.append(links)
    #else if not "Page not found" in soup.find("body").text:   
            #print("Cannot retrieve"+url)
    else:
        print("Cannot retrieve"+url)
    #print(links)
    
urls = ['https://ietresearch.onlinelibrary.wiley.com/toc/1751861x/2023/17/3-4','https://ietresearch.onlinelibrary.wiley.com/toc/1751861x/2023/17/2','https://ietresearch.onlinelibrary.wiley.com/toc/1751861x/2023/17/1',        'https://ietresearch.onlinelibrary.wiley.com/toc/1751861x/2022/16/5-6','https://ietresearch.onlinelibrary.wiley.com/toc/1751861x/2022/16/4','https://ietresearch.onlinelibrary.wiley.com/toc/1751861x/2022/16/2-3',        'https://ietresearch.onlinelibrary.wiley.com/toc/1751861x/2022/16/1','https://ietresearch.onlinelibrary.wiley.com/toc/1751861x/2021/15/6','https://ietresearch.onlinelibrary.wiley.com/toc/1751861x/2021/15/5',        'https://ietresearch.onlinelibrary.wiley.com/toc/1751861x/2021/15/4','https://ietresearch.onlinelibrary.wiley.com/toc/1751861x/2021/15/3','https://ietresearch.onlinelibrary.wiley.com/toc/1751861x/2021/15/2',
        'https://ietresearch.onlinelibrary.wiley.com/toc/1751861x/2021/15/1','https://ietresearch.onlinelibrary.wiley.com/toc/1751861x/2020/14/6','https://ietresearch.onlinelibrary.wiley.com/toc/1751861x/2020/14/5',        'https://ietresearch.onlinelibrary.wiley.com/toc/1751861x/2020/14/4','https://ietresearch.onlinelibrary.wiley.com/toc/1751861x/2020/14/3','https://ietresearch.onlinelibrary.wiley.com/toc/1751861x/2020/14/2','https://ietresearch.onlinelibrary.wiley.com/toc/1751861x/2020/14/1','https://ietresearch.onlinelibrary.wiley.com/toc/1751861x/2019/13/6','https://ietresearch.onlinelibrary.wiley.com/toc/1751861x/2019/13/5',
        'https://ietresearch.onlinelibrary.wiley.com/toc/1751861x/2019/13/4','https://ietresearch.onlinelibrary.wiley.com/toc/1751861x/2019/13/3','https://ietresearch.onlinelibrary.wiley.com/toc/1751861x/2019/13/2','https://ietresearch.onlinelibrary.wiley.com/toc/1751861x/2019/13/1','https://ietresearch.onlinelibrary.wiley.com/toc/1751861x/2018/12/6','https://ietresearch.onlinelibrary.wiley.com/toc/1751861x/2018/12/5','https://ietresearch.onlinelibrary.wiley.com/toc/1751861x/2018/12/4','https://ietresearch.onlinelibrary.wiley.com/toc/1751861x/2018/12/3',
        'https://ietresearch.onlinelibrary.wiley.com/toc/1751861x/2018/12/2','https://ietresearch.onlinelibrary.wiley.com/toc/1751861x/2018/12/1','https://ietresearch.onlinelibrary.wiley.com/toc/1751861x/2017/11/6','https://ietresearch.onlinelibrary.wiley.com/toc/1751861x/2017/11/5','https://ietresearch.onlinelibrary.wiley.com/toc/1751861x/2017/11/4','https://ietresearch.onlinelibrary.wiley.com/toc/1751861x/2017/11/3','https://ietresearch.onlinelibrary.wiley.com/toc/1751861x/2017/11/2','https://ietresearch.onlinelibrary.wiley.com/toc/1751861x/2017/11/1',
        'https://ietresearch.onlinelibrary.wiley.com/toc/1751861x/2016/10/6','https://ietresearch.onlinelibrary.wiley.com/toc/1751861x/2016/10/5','https://ietresearch.onlinelibrary.wiley.com/toc/1751861x/2016/10/4','https://ietresearch.onlinelibrary.wiley.com/toc/1751861x/2016/10/3','https://ietresearch.onlinelibrary.wiley.com/toc/1751861x/2016/10/2','https://ietresearch.onlinelibrary.wiley.com/toc/1751861x/2016/10/1','https://ietresearch.onlinelibrary.wiley.com/toc/1751861x/2015/9/6',
        'https://ietresearch.onlinelibrary.wiley.com/toc/1751861x/2015/9/5',   'https://ietresearch.onlinelibrary.wiley.com/toc/1751861x/2015/9/4',        'https://ietresearch.onlinelibrary.wiley.com/toc/1751861x/2015/9/3',        'https://ietresearch.onlinelibrary.wiley.com/toc/1751861x/2015/9/2',        'https://ietresearch.onlinelibrary.wiley.com/toc/1751861x/2015/9/1',        'https://ietresearch.onlinelibrary.wiley.com/toc/1751861x/2014/8/6',        'https://ietresearch.onlinelibrary.wiley.com/toc/1751861x/2014/8/5',        'https://ietresearch.onlinelibrary.wiley.com/toc/1751861x/2014/8/4',
        'https://ietresearch.onlinelibrary.wiley.com/toc/1751861x/2014/8/3',        'https://ietresearch.onlinelibrary.wiley.com/toc/1751861x/2014/8/2',        'https://ietresearch.onlinelibrary.wiley.com/toc/1751861x/2014/8/1',        'https://ietresearch.onlinelibrary.wiley.com/toc/1751861x/2013/7/6',        'https://ietresearch.onlinelibrary.wiley.com/toc/1751861x/2013/7/5',        'https://ietresearch.onlinelibrary.wiley.com/toc/1751861x/2013/7/4',        'https://ietresearch.onlinelibrary.wiley.com/toc/1751861x/2013/7/3',        'https://ietresearch.onlinelibrary.wiley.com/toc/1751861x/2013/7/2',
        'https://ietresearch.onlinelibrary.wiley.com/toc/1751861x/2013/7/1',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2023/17/17',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2023/17/16',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2023/17/15',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2023/17/14',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2023/17/13',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2023/17/12',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2023/17/11',
        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2023/17/10',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2023/17/9',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2023/17/8',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2023/17/7',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2023/17/6',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2023/17/5',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2023/17/4',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2023/17/3',
        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2023/17/2',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2023/17/1',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2022/16/18',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2022/16/17',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2022/16/16',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2022/16/15',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2022/16/14',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2022/16/13',
        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2022/16/12',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2022/16/11',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2022/16/10',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2022/16/9',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2022/16/8',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2022/16/7',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2022/16/6',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2022/16/5',
        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2022/16/4',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2022/16/3',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2022/16/2',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2022/16/1',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2021/15/18',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2021/15/17',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2021/15/16',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2021/15/15',
        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2021/15/14',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2021/15/13',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2021/15/12',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2021/15/11',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2021/15/10',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2021/15/9',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2021/15/8',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2021/15/7',
        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2021/15/6',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2021/15/5',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2021/15/4',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2021/15/3',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2021/15/2',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2021/15/1',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2020/14/20',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2020/14/19',
        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2020/14/18',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2020/14/17',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2020/14/16',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2020/14/15',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2020/14/14',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2020/14/13',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2020/14/12',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2020/14/11',
        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2020/14/10',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2020/14/9',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2020/14/8',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2020/14/7',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2020/14/6',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2020/14/5',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2020/14/4',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2020/14/3',
        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2020/14/2',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2020/14/1',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2019/13/18',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2019/13/17',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2019/13/16',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2019/13/15',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2019/13/14',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2019/13/13',
        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2019/13/12',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2019/13/11',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2019/13/10',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2019/13/9',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2019/13/8',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2019/13/7',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2019/13/6',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2019/13/5',
        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2019/13/4',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2019/13/3',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2019/13/2',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2019/13/1',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2018/12/18',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2018/12/17',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2018/12/16',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2018/12/15',
        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2018/12/14',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2018/12/13',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2018/12/12',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2018/12/11',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2018/12/10',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2018/12/9',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2018/12/8',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2018/12/7',
        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2018/12/6',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2018/12/5',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2018/12/4',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2018/12/3',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2018/12/2',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2018/12/1',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2017/11/18',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2017/11/17',
        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2017/11/16',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2017/11/15','https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2017/11/14','https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2017/11/13',        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2017/11/12','https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2017/11/11','https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2017/11/10','https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2017/11/9','https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2017/11/8',
        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2017/11/7','https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2017/11/6','https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2017/11/5','https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2017/11/4',       'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2017/11/3','https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2017/11/2','https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2017/11/1',
        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2016/10/18','https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2016/10/17','https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2016/10/16','https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2016/10/15','https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2016/10/14','https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2016/10/13',
        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2016/10/12','https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2016/10/11','https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2016/10/10','https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2016/10/9','https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2016/10/8','https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2016/10/7','https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2016/10/6','https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2016/10/5','https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2016/10/4','https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2016/10/3','https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2016/10/2',
'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2016/10/1','https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2015/9/18','https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2015/9/17','https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2015/9/16','https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2015/9/15','https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2015/9/14','https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2015/9/13','https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2015/9/12','https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2015/9/11','https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2015/9/10','https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2015/9/9',
        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2015/9/8','https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2015/9/7','https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2015/9/6','https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2015/9/5','https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2015/9/4','https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2015/9/3','https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2015/9/2','https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2015/9/1',
        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2014/8/18','https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2014/8/17','https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2014/8/16','https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2014/8/15','https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2014/8/14','https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2014/8/13','https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2014/8/12','https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2014/8/11','https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2014/8/10','https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2014/8/9',
        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2014/8/8','https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2014/8/7','https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2014/8/6','https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2014/8/5','https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2014/8/4','https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2014/8/3','https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2014/8/2','https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2014/8/1',
        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2013/7/18','https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2013/7/17','https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2013/7/16','https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2013/7/15','https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2013/7/14','https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2013/7/13','https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2013/7/12','https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2013/7/11','https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2013/7/10','https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2013/7/9',
        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2013/7/8','https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2013/7/7','https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2013/7/6','https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2013/7/5','https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2013/7/6','https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2013/7/5','https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2013/7/4',
        'https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2013/7/3','https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2013/7/2','https://ietresearch.onlinelibrary.wiley.com/toc/17518652/2013/7/1'
        
       ]
pdf_links = []
csv_output_path = 'iet_paper_links.csv'

for url in urls:
    extract_pdf_links_from_webpage(url, csv_output_path)
    time.sleep(25)

with open(csv_output_path, 'w', newline='', encoding='utf-8') as csv_file:
        writer = csv.writer(csv_file)
        #writer.writeheader()
        writer.writerows(pdf_links)
print(f"PDF links extracted and saved to '{csv_output_path}'")
# Out:
# https://ietresearch.onlinelibrary.wiley.com/toc/1751861x/2023/17/3-4
# https://ietresearch.onlinelibrary.wiley.com/toc/1751861x/2023/17/2
# https://ietresearch.onlinelibrary.wiley.com/toc/1751861x/2023/17/1
# https://ietresearch.onlinelibrary.wiley.com/toc/1751861x/2022/16/5-6
# https://ietresearch.onlinelibrary.wiley.com/toc/1751861x/2022/16/4
# https://ietresearch.onlinelibrary.wiley.com/toc/1751861x/2022/16/2-3
# https://ietresearch.onlinelibrary.wiley.com/toc/1751861x/2022/16/1
# https://ietresearch.onlinelibrary.wiley.com/toc/1751861x/2021/15/6
# https://ietresearch.onlinelibrary.wiley.com/toc/1751861x/2021/15/5
# https://ietresearch.onlinelibrary.wiley.com/toc/1751861x/2021/15/4
# https://ietresearch.onlinelibrary.wiley.com/toc/1751861x/2021/15/3
# https://ietresearch.onlinelibrary.wiley.com/toc/1751861x/2021/15/2
# https://ietresearch.onlinelibrary.wiley.com/toc/1751861x/2021/15/1
# https://ietresearch.onlinelibrary.wiley.com/toc/1751861x/2020/14/6
# ...

# %%
 print(s)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 print(s)
#
# NameError: name 's' is not defined

# %%
    
    with open(output_path, 'w', encoding='utf-8') as html_file:
        html_file.write(s)
        soup = BeautifulSoup(s, 'html5lib.parser')
    #print(s)
    # Find all elements with class 'PdfLink'
        for element in soup.find_all('PdfLink'):
            print("inside for loop")
            # Check if the element has an 'href' attribute
            if 'href' in element.attrs:
                pdf_url = element['href']
                pdf_links.append({'PDF URL': pdf_url})

        # Save PDF links to CSV file
                fields = ['PDF URL']
                with open(csv_output_path, 'w', newline='', encoding='utf-8') as csv_file:
                    writer = csv.DictWriter(csv_file, fieldnames=fields)
                    writer.writeheader()
                    writer.writerows(pdf_links)

                    print(f"PDF links extracted and saved to '{csv_output_path}'")
            else:
                print(f"Failed to fetch the webpage.")

# Example usage
