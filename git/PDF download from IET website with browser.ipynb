# %%
from selenium import webdriver
import time
# Path to your ChromeDriver. Update this with your path.
chrome_driver_path = 'C:\Program Files\Google\Chrome\Application\chrome.exe'

# URL of the webpage containing the embedded PDF
URLS = [
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12904',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12130',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12143',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12877',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12888',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12891',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12892',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12893',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12894',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12906',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12905',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12903',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12902',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12901',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12900',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12899',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12898',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12897',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12896',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12895',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12894',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12893',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12892',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12891',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12869',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12871',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12872',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12873',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12874',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12875',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12876',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12878',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12879',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12880',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12881',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12882',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12883',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12884',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12885',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12886',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12887',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12889',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12890',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12870',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12866',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12834',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12836',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12837',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12839',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12841',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12844',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12847',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12848',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12857',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12858',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12859',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12860',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12861',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12862',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12863',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12864',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12865',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12867',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12868',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12866',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12853',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12829',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12830',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12831',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12832',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12833',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12835',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12838',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12840',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12842',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12843',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12845',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12846',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12849',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12850',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12851',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12852',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12854',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12855',
'https://ietresearch.onlinelibrary.wiley.com/doi/epdf/10.1049/ipr2.12856',

      ]

# Set Chrome options to allow PDF download
chrome_options = webdriver.ChromeOptions()
prefs = {'plugins.always_open_pdf_externally': True}
chrome_options.add_experimental_option('prefs', prefs)

# Create a Chrome browser instance
browser = webdriver.Chrome(options=chrome_options)

for url in URLS:
# Open the webpage
    browser.get(url)
    time.sleep(20)
    #browser.quit()
# You might need to locate the element where the PDF is embedded and interact with it (e.g., click a download button or trigger the PDF to open)

# For example, if there's a button to download the PDF:
# pdf_download_button = browser.find_element_by_xpath("//xpath_of_the_download_button")
# pdf_download_button.click()

# Or if the PDF opens in a new tab, you might need to switch to that tab and save it using the browser

# Close the browser once the download is complete
#browser.quit()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 107
#     104 for url in URLS:
#     105 # Open the webpage
#     106     browser.get(url)
# --> 107     time.sleep(20)
#
# KeyboardInterrupt:
