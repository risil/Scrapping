# %%
import fitz  # PyMuPDF
import re
import os

# Specify the folder containing the PDF files
pdf_folder = 'E:\\NAAC\\iiqa'

# Regular expression for matching email addresses
email_regex = r'AISHE [A-Za-z]+\s+:\s+[A-Za-z]-[A-Za-z0-9]+'
trackID=r'Institution Track ID\s+:\s+[A-Za-z0-9]+'
trck2=r'AISHE [A-Za-z]+\s+:\s+[A-Za-z]-[A-Za-z0-9]+'

# Function to extract email addresses from a PDF file
def extract_emails_from_pdf(pdf_file):
    doc = fitz.open(pdf_file)
    text = ''
    
    for page_num in range(len(doc)):
        page = doc.load_page(page_num)
        text += page.get_text()

    emails = re.findall(email_regex, text)
    return emails

# List all PDF files in the folder
pdf_files = [f for f in os.listdir(pdf_folder) if f.endswith('.pdf')]

# Extract and print email addresses from each PDF
for pdf_file in pdf_files:
    pdf_path = os.path.join(pdf_folder, pdf_file)
    email_addresses = extract_emails_from_pdf(pdf_path)
    mcolln = "\n".join(email_addresses)
    if email_addresses:
        print(f'{pdf_file}:')
        mcoll = "\n".join(email_addresses)
        for email in email_addresses:
            print(email)

# You can also save the email addresses to a file if needed.
#file1=open(r"D:\\DOCILE\\dmails.txt","a")
#file1.writelines(mcolln)
file_path = "iiqa.txt"
with open(file_path, "w") as file:
    file.write(mcoll)
# Out:
# ADARSHA_SCIENCE_JAIRAMDAS_BHAGCHAND_ARTS_AND_BIRLA_COMMERCE_MAHAVIDYALAYA_DHAMANGAON_RLY_iiqa.pdf:
# AISHE ID
# :
# C-43042
# ADSUL39S_TECHNICAL_CAMPUS_iiqa.pdf:
# AISHE ID
# :
# C-45862
# ALDEL_EDUCATION_TRUST039S_ST._JOHN_COLLEGE_OF_HUMANITIES_AND_SCIENCES_iiqa.pdf:
# AISHE ID
# :
# C-45232
# AMRUTVAHINI_COLLEGE_OF_ENGINEERING_iiqa.pdf:
# AISHE ID
# :
# C-41515
# ARTS_COMMERCE_AND_SCIENCE_COLLEGE_LANJA_iiqa.pdf:
# AISHE ID
# :
# C-33676
# ASHOKA_EDUCATION_FOUNDATION039S_ASHOKA_COLLEGE_OF_EDUCATION_iiqa.pdf:
# AISHE ID
# :
# C-41585
# ASHOKA_INTERNATIONAL_CENTRE_FOR_EDUCATIONAL_STUDIES_AND_RESEARCH_iiqa.pdf:
# AISHE ID
# :
# C-44248
# Bajaj_College_of_Science_iiqa.pdf:
# AISHE ID
# :
# C-18638
# BALASAHEB_DESAI_COLLEGE_PATAN_iiqa.pdf:
# AISHE ID
# :
# C-10994
# BALIRAM_PATIL_ARTS_COMMERCE_AND_SCIENCE_COLLEGE_KINWAT._iiqa.pdf:
# AISHE ID
# :
# C-7353
# BALWANT_COLLEGE_VITA_iiqa.pdf:
# AISHE ID
# :
# C-11168
# BHARATIYA_MAHAVIDYALAYA_MORSHI_iiqa.pdf:
# AISHE ID
# :
# C-43096
# Bharat_Shikshan_Sansthas_Arts_Science_and_Commerce_College_Makni._iiqa.pdf:
# AISHE ID
# :
# C-34386
# BSPB039S_RADHAI_MAHAVIDHYALAYA_AURANGABAD_iiqa.pdf:
# AISHE ID
# :
# C-34263
# BUNTS_SANGHA39S_S.M.SHETTY_COLLEGE_OF_SCIENCE_COMMERCE_AND_MANAGEMENT_STUDIES_POWAI_iiqa.pdf:
# AISHE ID
# :
# C-34020
# CHINTAMANI_COLLEGE_OF_COMMERCE_POMBHURNA_DIST-_CHANDRAPUR_iiqa.pdf:
# AISHE ID
# :
# C-18232
# COLLEGE_OF_ENGINEERING_PUNE_iiqa.pdf:
# AISHE ID
# :
# C-41593
# COSMOPOLITIANS_VALIA_CHHAGANLAL_LALJIBHAI_COLLEGE_OF_COMMERCE_AND_VALIA_LILAVANTIBEN_CHHAGANLAL_COLLEGE_OF_ARTS_iiqa.pdf:
# AISHE ID
# :
# C-33842
# D.P._BHOSALE_COLLEGE_KOREGAON_iiqa.pdf:
# AISHE ID
# :
# C-11117
# DAHIWADI_COLLEGE_DAHIWADI_iiqa.pdf:
# AISHE ID
# :
# C-11193
# DATTA_MEGHE_INSTITUTE_OF_HIGHER_EDUCATION_AND_RESEARCH_DEEMED_TO_BE_UNIVERSITY_iiqa.pdf:
# AISHE ID
# :
# U-0295
# DAYANAND_EDUCATION_SOCIETY39S_DAYANAND_COLLEGE_OF_PHARMACY_LATUR._MAHARASHTRA_iiqa.pdf:
# AISHE ID
# :
# C-7586
# DES39S_SHRI_NAVALMAL_FIRODIA_LAW_COLLEGE_iiqa.pdf:
# AISHE ID
# :
# C-41635
# DESHBHAKT_BABASAHEB_BHAUSAHEB_KHANJIRE_SHIKSHAN_SANSTHA39S_NIGHT_COLLEGE_OF_ARTS_AND_COMMERCE_iiqa.pdf:
# AISHE ID
# :
# C-11228
# DNYANDEEP_MANDALS_ST._JOSEPH_COLLEGE_OF_ARTS_AND_COMMERCE_iiqa.pdf:
# AISHE ID
# :
# C-33564
# DR._AMBEDKAR_INSTITUTE_OF_MANAGEMENT_STUDIES_AND_RESEARCH_iiqa.pdf:
# AISHE ID
# :
# C-18898
# Dr._Babasaheb_Ambedkar_College_iiqa.pdf:
# AISHE ID
# :
# C-42156
# Dr._D._Y._Patil_Unitech_Societys_Dr._D._Y._Patil_Institute_of_Management_and_Research_iiqa.pdf:
# AISHE ID
# :
# C-42109
# DR._J._J._MAGDUM_COLLEGE_OF_ENGINEERING_JAYSINGPUR_iiqa.pdf:
# AISHE ID
# :
# C-11241
# DR._SAU._KAMALTAI_GAWAI_INSTITUTE_OF_ENGINEERING_AND_TECHNOLOGY_DARAPUR_iiqa.pdf:
# AISHE ID
# :
# C-43134
# DR._ULHAS_PATIL_MEDICAL_COLLEGE_AND_HOSPITAL_iiqa.pdf:
# AISHE ID
# :
# C-13807
# FERGUSSON_COLLEGEAUTONOMOUS_PUNE_iiqa.pdf:
# AISHE ID
# :
# C-41431
# FORESIGHT_COLLEGE_OF_COMMERCE_iiqa.pdf:
# AISHE ID
# :
# C-41344
# GAURISHANKAR_SEVA_SAMITI39S_VIDNYAN_MAHAVIDYALAYA_iiqa.pdf:
# AISHE ID
# :
# C-43210
# Government_College_of_Education_Dist_Akola_iiqa.pdf:
# AISHE ID
# :
# C-43058
# IES_COLLEGE_OF_ARCHITECTURE_iiqa.pdf:
# AISHE ID
# :
# C-33789
# INDIAN_INSTITUTE_OF_FOOD_SCIENCE_AND_TECHNOLOGY_iiqa.pdf:
# AISHE ID
# :
# C-44127
# INDIRA_COLLEGE_OF_PHARMACY_iiqa.pdf:
# AISHE ID
# :
# C-7622
# INSTITUTE_OF_COMPUTER_AND_MANAGEMENT_STUDIES_KASEGAON_PANDHARPUR_iiqa.pdf:
# AISHE ID
# :
# C-15723
# INSTITUTE_OF_PHARMACEUTICAL_EDUCATION_AND_RESEARCH_iiqa.pdf:
# AISHE ID
# :
# C-18462
# K._J._SOMAIYA_COLLEGE_OF_NURSING_iiqa.pdf:
# AISHE ID
# :
# C-13763
# KAPOL_VIDYANIDHI_COLLEGE_OF_HOTEL_MANAGEMENT_iiqa.pdf:
# AISHE ID
# :
# C-34096
# KARMAVIR_MAHAVIDYALAYAMUL_iiqa.pdf:
# AISHE ID
# :
# C-18369
# KHAIRUL_ISLAM_HIGHER_EDUCATION_SOCIETY39S_MAHARASHTRA_COLLEGE_OF_ARTS_SCIENCE_AND_COMMERCE._iiqa.pdf:
# AISHE ID
# :
# C-33903
# KOLHAPUR_INSTITUTE_OF_TECHNOLOGY39S_COLLEGE_OF_ENGINEERING_AUTONOMOUS_iiqa.pdf:
# AISHE ID
# :
# C-10996
# Konkan_Unnati_Mitra_Mandals_Vasantrao_Naik_College_of_Arts_Commerce_and_Barrister_A._R._Antulay_Science_College_Mhasala._iiqa.pdf:
# AISHE ID
# :
# C-34016
# KRISHNA_MAHAVIDYALAYA_RETHARE_BK_iiqa.pdf:
# AISHE ID
# :
# C-11209
# K_J_COLLEGE_OF_ENGINEERING_AND_MANAGEMENT_RESEARCH_iiqa.pdf:
# AISHE ID
# :
# C-42081
# LAL_BAHADUR_SHASTRI_SENIOR_COLLEGE_iiqa.pdf:
# AISHE ID
# :
# C-34290
# LATE_SHRI_YASHWANTRAO_CHAVAN_MEMORIAL_MEDICAL_AND_RURAL_DEVELOPMENT_FOUNDATION039S_DENTAL_COLLEGE_AND_HOSPITAL_AHMEDNAGAR_iiqa.pdf:
# AISHE ID
# :
# C-13910
# LOKMANYA_MAHAVIDYALAYA_iiqa.pdf:
# AISHE ID
# :
# C-18975
# M.G.E.Society039s_Huzurpaga_Shrimati_Durgabai_Mukunddas_Lohiya_Mahila_Vanijya_Mahavidyalaya_iiqa.pdf:
# AISHE ID
# :
# C-42063
# M.S.P._MANDAL039S_CHHATRAPATI_SHAHU_ARTS_COMMERCE_AND_SCIENCE_COLLEGE_LASUR_STATION_iiqa.pdf:
# AISHE ID
# :
# C-34374
# Maharshi_Karve_Stree_Shikshan_Samsthas_Shri._Siddhivinayak_Mahila_Mahavidyalaya_iiqa.pdf:
# AISHE ID
# :
# C-42012
# MAHATMA_GANDHI_INSTITUTE_OF_MEDICAL_SCIENCES_SEVAGRAM_WARDHA_MAHARASHTRA_iiqa.pdf:
# AISHE ID
# :
# C-14034
# MANDESH_MAHAVIDYALAYA_JUNONI_iiqa.pdf:
# AISHE ID
# :
# C-15794
# MANGHANMAL_UDHARAM_COLLEGE_OF_COMMERCE_iiqa.pdf:
# AISHE ID
# :
# C-41934
# MARATHWADA_MITRA_MANDALS_COLLEGE_OF_ENGINEERING_iiqa.pdf:
# AISHE ID
# :
# C-41309
# MARATHWADA_SHIKSHAN_PRASARAK_MANDAL039S_SHRI_MUKTANAND_COLLEGE_GANGAPUR_iiqa.pdf:
# AISHE ID
# :
# C-34294
# MATOSHRI_SHANTABAI_GOTE_ARTS_COMMERCE_AND_SCIENCE_COLLEGE_iiqa.pdf:
# AISHE ID
# :
# C-43109
# MATRUSHRI_KASHIBEN_MOTILAL_PATEL_SR_COLLEGE_OF_COMMERCE_SCIENCE_iiqa.pdf:
# AISHE ID
# :
# C-45246
# N._L._DALMIA_INSTITUTE_OF_MANAGEMENT_STUDIES_AND_RESEARCH_iiqa.pdf:
# AISHE ID
# :
# S-234
# NARAYANRAO_RANA_MAHAVIDYALAYA_BADNERA_NEW_TOWN_BADNERATQ_DIST_AMRAVATI._iiqa.pdf:
# AISHE ID
# :
# C-42988
# NAVGAN_SHIKSHAN_SANSTHA_RAJURIS__VASANTDADA_PATIL_ARTS_COMMERCE_AND_SCIENCE_COLLEGE_iiqa.pdf:
# AISHE ID
# :
# C-34370
# NAVSAHYADRI_CHARITABLE_TRUST_COLLEGE_OF_EDUCATION_iiqa.pdf:
# AISHE ID
# :
# C-42023
# NEW_ARTS_COMMERCE_AND_SCIENCE_COLLEGE_iiqa.pdf:
# AISHE ID
# :
# C-41346
# PANKAJ_SHAIKSHANIK_AND_SAMAJIK_SANSTHA_SANCHALIT_PANKAJ_KALA_MAHAVIDYALAYA_iiqa.pdf:
# AISHE ID
# :
# C-8878
# PIMPRI_CHINCHWAD_EDUCATION_TRUST039S_PIMPRI_CHINCHWAD_COLLEGE_OF_ENGINEERING_AND_RESEARCH_iiqa.pdf:
# AISHE ID
# :
# C-49660
# Pragat_Samajik_Shikshan_Society_Sanchalit_Dr._Babasaheb_Ambedkar_Science_Mahavadiyalaya_Advocate_Gurunath_Kulkarni_Commerce_and_Management_Mahavidyalaya_iiqa.pdf:
# AISHE ID
# :
# C-33829
# PRAGNYA_COLLEGE_OF_MANAGEMENT_AND_COMPUTER_STUDIES_iiqa.pdf:
# AISHE ID
# :
# C-41816
# PRAVARA_RURAL_EDUCATION_SOCIETY39S_ARTS_SCIENCE_AND_COMMERCE_COLLEGE_iiqa.pdf:
# AISHE ID
# :
# C-41993
# PUNE_DISTRICT_EDUCATION_ASSOCIATIONS_ANANTRAO_PAWAR_COLLEGE_PIRANGUT_iiqa.pdf:
# AISHE ID
# :
# C-41606
# RAJARSHI_CHHATRAPATI_SHAHU_COLLEGE_KOLHAPUR_iiqa.pdf:
# AISHE ID
# :
# C-11037
# RAJMATA_JIJAU_SHIKSHAN_PRASARAK_MANDAL039S_INSTITUE_OF_COMPUTER_AND_MANAGEMENT_RESEARCH_iiqa.pdf:
# AISHE ID
# :
# C-41462
# RAYAT_SHIKSHAN_SANSTHA039S_ARTS_SCIENCE_AND_COMMERCE_COLLEGE_iiqa.pdf:
# AISHE ID
# :
# C-34067
# RAYAT_SHIKSHAN_SANSTHA039S_DHANANJAYRAO_GADGIL_COLLEGE_OF_COMMERCE_iiqa.pdf:
# AISHE ID
# :
# C-11029
# RAYAT_SHIKSHAN_SANSTHA39S_DADA_PATIL_MAHAVIDYALAYA_iiqa.pdf:
# AISHE ID
# :
# C-41792
# RENUKA_COLLEGE_iiqa.pdf:
# AISHE ID
# :
# C-18562
# S.P.M.SCIENCE_AND_GILANI_ARTS_COMMERCE_COLLEGE_GHATANJI_iiqa.pdf:
# AISHE ID
# :
# C-43200
# S.S.V.P.SANSTHA39S_LATE_KARMVEER_DR._P.R.GHOGREY_SCIENCE_COLLEGE_iiqa.pdf:
# AISHE ID
# :
# C-8871
# SAHAKAR_MAHARSHI_LATE_BHASKARRAO_SHINGNE_ARTS_COLLEGEKHAMGAON._iiqa.pdf:
# AISHE ID
# :
# C-44892
# SAMAJ_SHIKSHAN_MANDAL_AMRUTESHWAR_ARTS_COMMERCE_AND_SCIENCE_COLLEGE_iiqa.pdf:
# AISHE ID
# :
# C-41472
# SAMBHAJIRAO_KENDRE_MAHAVIDYALAYA_JALKOT_DIST._LATIR_iiqa.pdf:
# AISHE ID
# :
# C-7452
# SANT_DNYANESHWAR_SHIKSHAN_SANSTH39S_ANNASAHEB_DANGE_COLLEGE_OF_ENGINEERING_AND_TECHNOLOGY_iiqa.pdf:
# AISHE ID
# :
# C-11099
# SARASWATI_DHANWANTARI_DENTAL_COLLEGE_AND_HOSPITAL_POST_GRADUATE_RESEARCH_INSTITUTE_iiqa.pdf:
# AISHE ID
# :
# C-13876
# SARASWATI_MANDIR_NIGHT_COLLEGE_OF_COMMERCE_AND_ARTS_iiqa.pdf:
# AISHE ID
# :
# C-41971
# SCTRS_PUNE_INSTITUTE_OF_COMPUTER_TECHNOLOGY_iiqa.pdf:
# AISHE ID
# :
# C-42072
# SHIVLINGESHWAR_COLLEGE_OF_PHARMACY_iiqa.pdf:
# AISHE ID
# :
# C-7600
# SHIVRAJ_COLLEGE_OF_ARTS_COMMERCE_AND_D._S._KADAM_SCIENCE_COLLEGE_GADHINGLAJ_iiqa.pdf:
# AISHE ID
# :
# C-11051
# SHRAMJIVI_SHIKSHAN_PRASARAK_MANDAL39S_ADARSH_MAHAVIDYALAYA_OMERGA_DIST._OSMANABAD_iiqa.pdf:
# AISHE ID
# :
# C-34537
# SHRIKRISHNA_MAHAVIDYALAYA_GUNJOTI_iiqa.pdf:
# AISHE ID
# :
# C-34393
# SHRIMAN_BHAUSAHEB_ZADBUKE_MAHAVIDYALAYA_BARSHI_iiqa.pdf:
# AISHE ID
# :
# C-15683
# SHRI_AMOLAK_JAIN_VIDYA_PRASARAK_MANDAL39S_SMT._S._K._GANDHI_ARTS_AMOLAK_SCIENCE_AND_P._H._GANDHI_COMMERCE_COLLEGE_KADA_TAL._ASHTI_DIST._BEED_iiqa.pdf:
# AISHE ID
# :
# C-34612
# SHRI_DR._R._G._RATHOD_ARTS_AND_SCIENCE_COLLEGE_MURTIZAPUR_DIST._AKOLA_iiqa.pdf:
# AISHE ID
# :
# C-43095
# Shri_Ganesh_Kala_Mahavidyalaya_iiqa.pdf:
# AISHE ID
# :
# C-43223
# SHRI_JAYKUMAR_RAWAL_INSTITUTE_OF_TECHNOLOGY_iiqa.pdf:
# AISHE ID
# :
# C-49529
# SHRI_MATHURADAS_MOHOTA_COLLEGE_OF_SCIENCE_iiqa.pdf:
# AISHE ID
# :
# C-18693
# SHRI_PADMAMANI_JAIN_ARTS_AND_COMMERCE_COLLEGE_iiqa.pdf:
# AISHE ID
# :
# C-41327
# Shri_Pundlik_Maharaj_Mahavidyalaya_Nandura_Rly._iiqa.pdf:
# AISHE ID
# :
# C-42953
# SHRI_SANT_JANABAI_EDUCATION_SOCIETY39S_ARTS_COMMERCE_AND_SCIENCE_COLLEGE_GANGAKHED_iiqa.pdf:
# AISHE ID
# :
# C-7273
# SHRI_SWAMI_VIVEKANAND_SHIKSHAN_SANSTHA39S_ARTS_AND_COMMERCE_COLLEGE_iiqa.pdf:
# AISHE ID
# :
# C-10999
# SHRI_VITTHALRAO_SHANKARRAO_NAIK_ARTS_COMMERCE_AND_SCIENCE_COLLEGE_RAVER_MAHARASHTRA_425508_iiqa.pdf:
# AISHE ID
# :
# C-8856
# SHRI_YOGESHWARI_EDUCATION_SOCIETY39S_YOGESHWARI_MAHAVIDYALAYA_iiqa.pdf:
# AISHE ID
# :
# C-34366
# SINHGAD_TECHNICAL_EDUCATION_SOCIETY_RASIKLAL_M._DHARIWAL_SINHGAD_TECHNICAL_INSTITUTES_CAMPUS_iiqa.pdf:
# AISHE ID
# :
# C-45896
# SIPNA_COLLEGE_OF_ENGINEERING_AND_TECHNOLOGY_AMRAVATI_iiqa.pdf:
# AISHE ID
# :
# C-43142
# SMT._DANKUNWAR_MAHILA_MAHAVIDYALAYA_iiqa.pdf:
# AISHE ID
# :
# C-34553
# Smt._P._N._Doshi_Womens_College_of_Arts_Kum_U._R._Shah_Womens_College_of_Commerce_and_Dr._Smt._Nanavati_Bhanuben_Mahendra_Womens_College_of_Home_Science_iiqa.pdf:
# AISHE ID
# :
# C-44172
# SMT._VIMLADEVI_AYURVEDIC_MEDICAL_COLLEGE_AND_HOSPITAL_AT._PO._TADALI_VILLAGE_WANDHARI_DIST._CHANDRAPUR_iiqa.pdf:
# AISHE ID
# :
# C-13922
# SMT_SINDHUTAI_JADHAO_ARTS_AND_SCIENCE_MAHAVIDYALAYA_MEHKAR_DIST_BULDANA_iiqa.pdf:
# AISHE ID
# :
# C-43078
# ST._GONSALO_GARCIA_COLLEGE_OF_ARTS_COMMERCE_iiqa.pdf:
# AISHE ID
# :
# C-34109
# SURYODAYA_COLLEGE_OF_ENGINEERING_AND_TECHNOLOGY_NAGPUR_iiqa.pdf:
# AISHE ID
# :
# C-18449
# TIRPUDE_INSTITUTE_OF_MANAGEMENT_EDUCATION_iiqa.pdf:
# AISHE ID
# :
# C-18383
# TRIMURTI_SHIKSHAN_SANSTHA39S_SMT._VIMALBAI_UTTAMRAO_PATIL_ARTS_AND_LATE_DR._BHASKAR_SADASHIV_DESALE_SCIENCE_COLLEGE_SAKRI_TAL-_SAKRI_DISTT._DHULE_iiqa.pdf:
# AISHE ID
# :
# C-8923
# VIDYAWARDHINI_SABHA39S_ARTS_COMMERCE_AND_SCIENCE_COLLEGE_DHULE_iiqa.pdf:
# AISHE ID
# :
# C-8867
# VIDYA_PRATISHTHANS_SUPE_ARTS_SCIENCE_AND_COMMERCE_COLLEGE_SUPE_TAL._BARAMATI_iiqa.pdf:
# AISHE ID
# :
# C-59363
# Vishnu_Waman_Thakur_Charitable_Trust039s_Viva_Institute_Of_Technology_iiqa.pdf:
# AISHE ID
# :
# C-34168
# Vitthalrao_Patil_Mahavidyalaya_Arts_Commerce_and_Science_KALE_Tal-_Panhala_Dist._Kolhapur_iiqa.pdf:
# AISHE ID
# :
# C-11239
# WALCHAND_COLLEGE_OF_ENGINEERING_iiqa.pdf:
# AISHE ID
# :
# C-11015
# YASHODA_GIRLS39_ARTS_AND_COMMERCE_COLLEGE_NAGPUR_iiqa.pdf:
# AISHE ID
# :
# C-18557
# YASH_INSTITUTE_OF_PHARMACY_iiqa.pdf:
# AISHE ID
# :
# C-34256
