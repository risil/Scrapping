# %%
from pdf2docx import Converter
pdf_file = '3.pdf'
docx_file = 'd:\\roadmap.docx'
cv = Converter(pdf_file)
cv.convert(docx_file)
cv.close
# Out:
# [INFO] Start to convert 3.pdf
# [INFO] [1/4] Opening document...
# [INFO] [2/4] Analyzing document...
# [WARNING] Ignore Line "" due to overlap
# [WARNING] Ignore Line "" due to overlap
# [WARNING] Ignore Line "established sectoral universities such as " due to overlap
# [INFO] [3/4] Parsing pages...
# [INFO] (1/120) Page 1
# [INFO] (2/120) Page 2
# [INFO] (3/120) Page 3
# [INFO] (4/120) Page 4
# [INFO] (5/120) Page 5
# [INFO] (6/120) Page 6
# [INFO] (7/120) Page 7
# [INFO] (8/120) Page 8
# [INFO] (9/120) Page 9
# [INFO] (10/120) Page 10
# [INFO] (11/120) Page 11
# [INFO] (12/120) Page 12
# [INFO] (13/120) Page 13
# [INFO] (14/120) Page 14
# [INFO] (15/120) Page 15
# [INFO] (16/120) Page 16
# [INFO] (17/120) Page 17
# [INFO] (18/120) Page 18
# [INFO] (19/120) Page 19
# [INFO] (20/120) Page 20
# [INFO] (21/120) Page 21
# [INFO] (22/120) Page 22
# [INFO] (23/120) Page 23
# [INFO] (24/120) Page 24
# [INFO] (25/120) Page 25
# [INFO] (26/120) Page 26
# [INFO] (27/120) Page 27
# ...
