# %%
import re 
import os
import pdfminer
import pdfminer.high_level
from pdfminer.high_level import extract_text 

pdf_folder = 'D:\\DOCILE\\dergipark'
def extract_emails(pdf_path): 
    emails = set() 
    for page_num in range(1, extract_text(pdf_path, page_numbers=[i for i in range(1, 1000)]).count('\n')): 
        text = extract_text(pdf_path, page_numbers=[page_num]) 
        matches = re.findall(r'\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Z|a-z]{2,7}\b', text) 
        for match in matches: 
            emails.add(match) 
    return emails

# %%
# Out:
# {'ekremtoparlak@gmail.com', 'haluk.egeli@gmail.com', 'ssakinc@hotmail.com', 'optimumdergi@usak.edu.tr', 'yenilmez@ogu.edu.tr', 'adilya.yamaltdinova@manas.edu.kg', 'abdulkerim.eroglu@deu.edu.tr', 'mahmut.erdogan@manas.edu.kg', 'selcuk349@hotmail.com', 'salih.arslan@bilecik.edu.tr', 'mustafa.taytak@usak.edu.tr', 'mustafagullu@gmail.com'}

# %%
# List all PDF files in the folder
pdf_files = [f for f in os.listdir(pdf_folder) if f.endswith('.pdf')]
mcolln = set() 
# Extract and print email addresses from each PDF
for pdf_file in pdf_files:
    pdf_path = os.path.join(pdf_folder, pdf_file)
    print(f'{pdf_file}:')
    emails = extract_emails(pdf_path)
    mcolln = "\n".join(emails)
    if emails:
        print(f'{pdf_file}:')
        for email in emails:
            print(email)
            
file1=open(r"D:\\DOCILE\\mails.txt","a")
file1.writelines(mcolln)
# Out:
# 10.21605-cukurovaummfd.357271-369778.pdf:
# 1_Galecka_Smolny.pdf:
# 2015_AAST_RESD_VOL1_ISSUE1_FULL_VERSION.pdf:
# 2015_AAST_RESD_VOL1_ISSUE1_FULL_VERSION.pdf:
# ahmed.abdel-salam@ieee.org
# abdelaziz.boukara@marseille.archi.fr
# omarispower@hotmail.com
# kamal@ele.etsmtl.ca
# fernando@autom.uva.es
# h_parastvand@sut.ac.ir
# aliismail@aast.edu
# markidesmarina@gmail.com
# rania@aast.edu
# rsalem02@yahoo.fr
# maghni_1990@yahoo.fr
# ygd@aast.edu
# khosrowjerdi@sut.ac.ir
# mismail@hanyang.ac.kr
# Layachi40@yahoo.fr
# aya.diab@eng.asu.edu.eg
# souracha2005@yahoo.fr
# Nacer.msirdi@lsis.org
# despina.serghides@cut.ac.cy
# aziz.naamane@lsis.org
# al.taweel@dal.ca
# galallelsayed@gmail.com
# rmili_lazhar@yahoo.fr
# Abdallahsaadoun555@gmial.com
# Safwat.seleem@yahoo.com
# martha.katafygiotou@cut.ac.cy
# yahoo.frmeziane_elc@yahoo.fr
# tarekelgeziry@yahoo.com
# nacer.msirdi@lsis.org
# khaled.sakty@aast.edu
# 2015_AAST_RESD_VOL1_ISSUE2_FULL_VERSION.pdf:
# ...

# %%
emails = extract_emails('D:\\DOCILE\\dergipark\\5a54aa658363e.pdf')
print(emails)
