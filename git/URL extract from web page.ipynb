# %%
import requests
from bs4 import BeautifulSoup

# URLs to fetch data from
urls = [
    'https://assessmentonline.naac.gov.in/storage/app/aqar/', '''
    'https://dbjournal.ro/32.html',
'https://dbjournal.ro/31.html',
'https://dbjournal.ro/31.html',
'https://dbjournal.ro/31.html',
'https://dbjournal.ro/30.html',
'https://dbjournal.ro/29.html',
'https://dbjournal.ro/28.html',
'https://dbjournal.ro/27.html',
'https://dbjournal.ro/26.html',
'https://dbjournal.ro/25.html',
'https://dbjournal.ro/24.html',
'https://dbjournal.ro/23.html',
'https://dbjournal.ro/22.html',
'https://dbjournal.ro/21.html',
'https://dbjournal.ro/20.html',
'https://dbjournal.ro/19.html',
'https://dbjournal.ro/18.html',
'https://dbjournal.ro/17.html',
'https://dbjournal.ro/16.html',
'https://dbjournal.ro/15.html',
'https://dbjournal.ro/14.html',
'https://dbjournal.ro/13.html',
'https://dbjournal.ro/12.html',
'https://dbjournal.ro/11.html',
'https://dbjournal.ro/10.html',
'https://dbjournal.ro/9.html',
'https://dbjournal.ro/8.html',
'https://dbjournal.ro/7.html',
'https://dbjournal.ro/6.html',
'https://dbjournal.ro/5.html',
'https://dbjournal.ro/4.html',
'https://dbjournal.ro/3.html',
'https://dbjournal.ro/2.html',
'https://dbjournal.ro/1.html','''

    
    # Add more URLs as needed
]

# Function to extract hyperlinks from a URL
def extract_links_from_url(url):
    try:
        response = requests.get(url)
        if response.status_code == 200:
            soup = BeautifulSoup(response.content, 'html.parser')
            links = [link.get('href') for link in soup.find_all('a') if link.get('href')]
            return links
    except requests.RequestException as e:
        print(f"Error fetching {url}: {e}")
    return []

# Extract and print hyperlinks for each URL
for url in urls:
    print(f"Links for {url}:")
    extracted_links = extract_links_from_url(url)
    for link in extracted_links:
        if "pdf" in link:
            print(link)
    print()
# Out:
# Links for https://assessmentonline.naac.gov.in/storage/app/aqar/:
# Error fetching https://assessmentonline.naac.gov.in/storage/app/aqar/: HTTPSConnectionPool(host='assessmentonline.naac.gov.in', port=443): Max retries exceeded with url: /storage/app/aqar/ (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1002)')))
#
# Links for
#     'https://dbjournal.ro/32.html',
# 'https://dbjournal.ro/31.html',
# 'https://dbjournal.ro/31.html',
# 'https://dbjournal.ro/31.html',
# 'https://dbjournal.ro/30.html',
# 'https://dbjournal.ro/29.html',
# 'https://dbjournal.ro/28.html',
# 'https://dbjournal.ro/27.html',
# 'https://dbjournal.ro/26.html',
# 'https://dbjournal.ro/25.html',
# 'https://dbjournal.ro/24.html',
# 'https://dbjournal.ro/23.html',
# 'https://dbjournal.ro/22.html',
# 'https://dbjournal.ro/21.html',
# 'https://dbjournal.ro/20.html',
# 'https://dbjournal.ro/19.html',
# ...

# %%
import requests
from bs4 import BeautifulSoup

# URLs to fetch data from
urls = [
    'https://www.mdpi.com/1424-8220/21/1',
    'https://www.mdpi.com/1424-8220/21/2',
    'https://www.mdpi.com/1424-8220/21/3',
    'https://www.mdpi.com/1424-8220/21/4',
    'https://www.mdpi.com/1424-8220/21/5',
    'https://www.mdpi.com/1424-8220/21/6',
    'https://www.mdpi.com/1424-8220/21/7',
    'https://www.mdpi.com/1424-8220/21/8',
    'https://www.mdpi.com/1424-8220/21/9',
    'https://www.mdpi.com/1424-8220/21/10',
    'https://www.mdpi.com/1424-8220/21/11',
    'https://www.mdpi.com/1424-8220/21/12',
    'https://www.mdpi.com/1424-8220/21/13',
    'https://www.mdpi.com/1424-8220/21/14',
    'https://www.mdpi.com/1424-8220/21/15',
    'https://www.mdpi.com/1424-8220/21/16',
    'https://www.mdpi.com/1424-8220/21/17',
    'https://www.mdpi.com/1424-8220/21/18',    
    'https://www.mdpi.com/1424-8220/21/19',
    'https://www.mdpi.com/1424-8220/21/20',
    'https://www.mdpi.com/1424-8220/21/21',
    'https://www.mdpi.com/1424-8220/21/22',
    'https://www.mdpi.com/1424-8220/21/23',
    'https://www.mdpi.com/1424-8220/21/24',
    'https://www.mdpi.com/1424-8220/22/1',
    'https://www.mdpi.com/1424-8220/22/2',
    'https://www.mdpi.com/1424-8220/22/3',
    'https://www.mdpi.com/1424-8220/22/4',
    'https://www.mdpi.com/1424-8220/22/5',
    'https://www.mdpi.com/1424-8220/22/6',
    'https://www.mdpi.com/1424-8220/22/7',
    'https://www.mdpi.com/1424-8220/22/8',
    'https://www.mdpi.com/1424-8220/22/9',
    'https://www.mdpi.com/1424-8220/22/10',
    'https://www.mdpi.com/1424-8220/22/11',
    'https://www.mdpi.com/1424-8220/22/12',
    'https://www.mdpi.com/1424-8220/22/13',
    'https://www.mdpi.com/1424-8220/22/14',
    'https://www.mdpi.com/1424-8220/22/15',
    'https://www.mdpi.com/1424-8220/22/16',
    'https://www.mdpi.com/1424-8220/22/17',
    'https://www.mdpi.com/1424-8220/22/18',    
    'https://www.mdpi.com/1424-8220/22/19',
    'https://www.mdpi.com/1424-8220/22/20',
    'https://www.mdpi.com/1424-8220/22/21',
    'https://www.mdpi.com/1424-8220/22/22',
    'https://www.mdpi.com/1424-8220/22/23',
    'https://www.mdpi.com/1424-8220/22/24',
    'https://www.mdpi.com/1424-8220/23/1',
    'https://www.mdpi.com/1424-8220/23/2',
    'https://www.mdpi.com/1424-8220/23/3',
    'https://www.mdpi.com/1424-8220/23/4',
    'https://www.mdpi.com/1424-8220/23/5',
    'https://www.mdpi.com/1424-8220/23/6',
    'https://www.mdpi.com/1424-8220/23/7',
    'https://www.mdpi.com/1424-8220/23/8',
    'https://www.mdpi.com/1424-8220/23/9',
    'https://www.mdpi.com/1424-8220/23/10',
    'https://www.mdpi.com/1424-8220/23/11',
    'https://www.mdpi.com/1424-8220/23/12',
    'https://www.mdpi.com/1424-8220/23/13',
    'https://www.mdpi.com/1424-8220/23/14',
    'https://www.mdpi.com/1424-8220/23/15',
    'https://www.mdpi.com/1424-8220/23/16',
    'https://www.mdpi.com/1424-8220/23/17',
    'https://www.mdpi.com/1424-8220/23/18',
    'https://www.mdpi.com/1424-8220/23/19',
    # Add more URLs as needed
]

# Function to extract hyperlinks from a URL
def extract_urls_from_multiple_pages(base_url, num_pages):
    all_urls = []
    for page_num in range(1, num_pages + 1):
        try:
            url = f"{base_url}{page_num}"
            response = requests.get(url)
            if response.status_code == 200:
                soup = BeautifulSoup(response.content, 'html.parser')
                urls = [link.get('href') for link in soup.find_all('a') if link.get('href')]
                all_urls.extend(urls)
        except requests.RequestException as e:
            print(f"Error fetching {url}: {e}")
    return all_urls

# Extract and print hyperlinks for each URL
for url in urls:
    print(f"Links for {url}:")
    extracted_links = extract_links_from_url(url)
    for link in extracted_links:
        if "pdf" in link:
            print(link)
    print()
# Out:
# Links for https://www.mdpi.com/1424-8220/21/1:
# /1424-8220/21/1/320/pdf?version=1609988317
# /1424-8220/21/1/319/pdf?version=1610005719
# /1424-8220/21/1/318/pdf?version=1609900759
# /1424-8220/21/1/317/pdf?version=1609901423
# /1424-8220/21/1/316/pdf?version=1610104242
# /1424-8220/21/1/315/pdf?version=1609983225
# /1424-8220/21/1/314/pdf?version=1609999026
# /1424-8220/21/1/313/pdf?version=1609860615
# /1424-8220/21/1/312/pdf?version=1609929338
# /1424-8220/21/1/311/pdf?version=1609930008
# /1424-8220/21/1/310/pdf?version=1609990694
# /1424-8220/21/1/309/pdf?version=1609910138
# /1424-8220/21/1/308/pdf?version=1610012538
# /1424-8220/21/1/307/pdf?version=1610001323
# /1424-8220/21/1/306/pdf?version=1609841642
# /1424-8220/21/1/305/pdf?version=1609991005
# /1424-8220/21/1/304/pdf?version=1609918859
# /1424-8220/21/1/303/pdf?version=1610021931
# /1424-8220/21/1/302/pdf?version=1610000102
# /1424-8220/21/1/301/pdf?version=1609845813
# /1424-8220/21/1/300/pdf?version=1609834185
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service as ChromeService
from selenium.webdriver.common.by import By
import time
import requests
from bs4 import BeautifulSoup
import csv
import sys
# URL of the webpage to extract URLs from
urls = [
    'https://www.mdpi.com/1424-8220/21/1',
    'https://www.mdpi.com/1424-8220/21/2',
    'https://www.mdpi.com/1424-8220/21/3',
    'https://www.mdpi.com/1424-8220/21/4',
    'https://www.mdpi.com/1424-8220/21/5',
    'https://www.mdpi.com/1424-8220/21/6',
    'https://www.mdpi.com/1424-8220/21/7',
    'https://www.mdpi.com/1424-8220/21/8',
    'https://www.mdpi.com/1424-8220/21/9',
    'https://www.mdpi.com/1424-8220/21/10',
    'https://www.mdpi.com/1424-8220/21/11',
    'https://www.mdpi.com/1424-8220/21/12',
    'https://www.mdpi.com/1424-8220/21/13',
    'https://www.mdpi.com/1424-8220/21/14',
    'https://www.mdpi.com/1424-8220/21/15',
    'https://www.mdpi.com/1424-8220/21/16',
    'https://www.mdpi.com/1424-8220/21/17',
    'https://www.mdpi.com/1424-8220/21/18',    
    'https://www.mdpi.com/1424-8220/21/19',
    'https://www.mdpi.com/1424-8220/21/20',
    'https://www.mdpi.com/1424-8220/21/21',
    'https://www.mdpi.com/1424-8220/21/22',
    'https://www.mdpi.com/1424-8220/21/23',
    'https://www.mdpi.com/1424-8220/21/24',
    'https://www.mdpi.com/1424-8220/22/1',
    'https://www.mdpi.com/1424-8220/22/2',
    'https://www.mdpi.com/1424-8220/22/3',
    'https://www.mdpi.com/1424-8220/22/4',
    'https://www.mdpi.com/1424-8220/22/5',
'https://www.mdpi.com/1424-8220/18/22',
'https://www.mdpi.com/1424-8220/18/23',
'https://www.mdpi.com/1424-8220/18/24',
'https://www.mdpi.com/1424-8220/19/1',
'https://www.mdpi.com/1424-8220/19/2',
'https://www.mdpi.com/1424-8220/19/3',
'https://www.mdpi.com/1424-8220/19/4',
'https://www.mdpi.com/1424-8220/19/5',
'https://www.mdpi.com/1424-8220/19/6',
'https://www.mdpi.com/1424-8220/19/7',
'https://www.mdpi.com/1424-8220/19/8',
'https://www.mdpi.com/1424-8220/19/9',
'https://www.mdpi.com/1424-8220/19/10',
'https://www.mdpi.com/1424-8220/19/11',
'https://www.mdpi.com/1424-8220/19/12',
'https://www.mdpi.com/1424-8220/19/13',
'https://www.mdpi.com/1424-8220/19/14',
'https://www.mdpi.com/1424-8220/19/15',
'https://www.mdpi.com/1424-8220/19/16',
'https://www.mdpi.com/1424-8220/19/17',
'https://www.mdpi.com/1424-8220/19/18',
'https://www.mdpi.com/1424-8220/19/19',
'https://www.mdpi.com/1424-8220/19/20',
'https://www.mdpi.com/1424-8220/19/21',
'https://www.mdpi.com/1424-8220/19/22',
'https://www.mdpi.com/1424-8220/19/23',
'https://www.mdpi.com/1424-8220/19/24',
'https://www.mdpi.com/1424-8220/20/1',
'https://www.mdpi.com/1424-8220/20/2',
'https://www.mdpi.com/1424-8220/20/3',
'https://www.mdpi.com/1424-8220/20/4',
'https://www.mdpi.com/1424-8220/20/5',
'https://www.mdpi.com/1424-8220/20/6',
'https://www.mdpi.com/1424-8220/20/7',
'https://www.mdpi.com/1424-8220/20/8',
'https://www.mdpi.com/1424-8220/20/9',
'https://www.mdpi.com/1424-8220/20/10',
'https://www.mdpi.com/1424-8220/20/11',
'https://www.mdpi.com/1424-8220/20/12',
'https://www.mdpi.com/1424-8220/20/13',
'https://www.mdpi.com/1424-8220/20/14',
'https://www.mdpi.com/1424-8220/20/15',
'https://www.mdpi.com/1424-8220/20/16',
'https://www.mdpi.com/1424-8220/20/17',
'https://www.mdpi.com/1424-8220/20/18',
'https://www.mdpi.com/1424-8220/20/19',
'https://www.mdpi.com/1424-8220/20/20',
'https://www.mdpi.com/1424-8220/20/21',
'https://www.mdpi.com/1424-8220/20/22',
'https://www.mdpi.com/1424-8220/20/23',
'https://www.mdpi.com/1424-8220/20/24',

    # Add more URLs as needed
]
csv_filename = "Sensor_journal.csv"
old_stdout = sys.stdout
sys.stdout = open(csv_filename, 'a')
# Function to scroll and extract all hyperlinks
def scroll_and_extract_links(url):
    driver = webdriver.Chrome()  # Initialize your preferred web driver

    driver.get(url)
    last_height = driver.execute_script("return document.body.scrollHeight")

    while True:
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(2)  # Adjust sleep time as needed

        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            break
        last_height = new_height

    links = driver.find_elements(By.TAG_NAME, 'a')
    hrefs = [link.get_attribute('href') for link in links]
    
    driver.quit()
    return hrefs
# Extract and print hyperlinks for each URL
for url in urls:
    print(f"Links for {url}:")
    # Extract and print all URLs after scrolling
    extracted_links = scroll_and_extract_links(url)
    print("All URLs:")
    if extracted_links is not None:
        for link in extracted_links:
            if link is not None and "pdf" in link:
                print(link)
print()
